# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
from selenium import webdriver

# %%
import time

# %%
CursorUSA = ['eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo1NCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo5MCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMDgsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMjYsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNDQsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNjIsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOTgsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMTYsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMzQsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyNTIsInZlcnNpb24iOjF9']
CursorEurope = ['eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo1NCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo5MCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMDgsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMjYsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNDQsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNjIsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOTgsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMTYsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMzQsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyNTIsInZlcnNpb24iOjF9']
CursorSouthAmerica = ['eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo1NCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo5MCwidmVyc2lvbiI6MX0%3D', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMDgsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMjYsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNDQsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNjIsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOTgsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMTYsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMzQsInZlcnNpb24iOjF9', 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyNTIsInZlcnNpb24iOjF9']
CursorTurkey = ['eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo1NCwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo5MCwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMDgsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMjYsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNDQsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNjIsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOTgsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMTYsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMzQsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyNTIsInZlcnNpb24iOjF9']
CursorItaly =['eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo1NCwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo3MiwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0Ijo5MCwidmVyc2lvbiI6MX0%3D',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMDgsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxMjYsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNDQsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxNjIsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxODAsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOTgsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMTYsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyMzQsInZlcnNpb24iOjF9',
 'eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoyNTIsInZlcnNpb24iOjF9']

# %%
links = {
    "https://www.airbnb.ru/s/%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&place_id=ChIJhdqtz4aI7UYRefD8s-aZ73I&date_picker_type=calendar&checkin=2024-01-01&checkout=2024-01-31&source=structured_search_input_header&search_type=filter_change&query=%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0&price_filter_num_nights=30&federated_search_session_id=54418551-df51-4f4c-884b-a85f314a556c&pagination_search=true&cursor=": CursorEurope,
    "https://www.airbnb.ru/s/%D0%A1%D0%A8%D0%90/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&date_picker_type=calendar&checkin=2024-01-01&checkout=2024-01-31&source=structured_search_input_header&search_type=unknown&price_filter_num_nights=30&place_id=ChIJCzYy5IS16lQRQrfeQ5K5Oxw&query=%D0%A1%D0%A8%D0%90&federated_search_session_id=58340a9f-b19d-4722-a0ea-14900adae141&pagination_search=true&cursor=": CursorUSA,
    "https://www.airbnb.ru/s/%D0%AE%D0%B6%D0%BD%D0%B0%D1%8F-%D0%90%D0%BC%D0%B5%D1%80%D0%B8%D0%BA%D0%B0/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&date_picker_type=calendar&checkin=2024-01-01&checkout=2024-01-31&source=structured_search_input_header&search_type=unknown&price_filter_num_nights=30&place_id=ChIJtTRdNRw0CZQRK-PGyc8M1Gk&query=%D0%AE%D0%B6%D0%BD%D0%B0%D1%8F%20%D0%90%D0%BC%D0%B5%D1%80%D0%B8%D0%BA%D0%B0&federated_search_session_id=2625d39f-073e-4891-b280-3cd600a29361&pagination_search=true&cursor=": CursorSouthAmerica,
    "https://www.airbnb.ru/s/%D0%A2%D1%83%D1%80%D1%86%D0%B8%D1%8F/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=1&price_filter_input_type=0&channel=EXPLORE&place_id=ChIJcSZPllwVsBQRKl9iKtTb2UA&date_picker_type=monthly_stay&source=structured_search_input_header&search_type=filter_change&query=%D0%A2%D1%83%D1%80%D1%86%D0%B8%D1%8F&price_filter_num_nights=31&federated_search_session_id=c626cfbb-7800-4f5a-af6e-01c92808e297&pagination_search=true&cursor=": CursorTurkey,
    "https://www.airbnb.ru/s/%D0%98%D1%82%D0%B0%D0%BB%D0%B8%D1%8F/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=1&price_filter_input_type=0&channel=EXPLORE&date_picker_type=monthly_stay&source=structured_search_input_header&search_type=unknown&price_filter_num_nights=31&place_id=ChIJA9KNRIL-1BIRb15jJFz1LOI&query=%D0%98%D1%82%D0%B0%D0%BB%D0%B8%D1%8F&federated_search_session_id=fdaf522b-8a32-460d-8ce0-5c3a26beed4a&pagination_search=true&cursor=": CursorItaly
}

# %%
def convertToFloat(n):
    try:
        n = float(n)
        return True
    except:
        return False

# %%
region = []
placeInCountry = []
country = []
rating = []
descriptionHotel = []
quantityOfBed = []
typeOfBuilding = []
amount = []

driver = webdriver.Chrome()
for k in links:
    for j in links[k]:
        print(k+j)
        driver.get(k+j)
        time.sleep(60)
        html_text = driver.page_source
        soup = BeautifulSoup(html_text)
        all_ads = soup.find_all("div", class_="g1qv1ctd atm_u80d3j_1lqfgyr atm_c8_o7aogt atm_g3_8jkm7i c1v0rf5q atm_9s_11p5wf0 atm_cx_d64hb6 atm_dz_7esijk atm_e0_1lo05zz dir dir-ltr")
        for i in all_ads:
            region.append("Europe")
            titleHotels = i.find("div", class_ = "t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr")
            if len(titleHotels.text.strip().split(", ")) < 2:
                continue
            typeOfBuilding.append(titleHotels and titleHotels.text.strip().split(',')[0] or None)
            print(titleHotels)
            cityCountry = titleHotels and titleHotels.text.strip().split(", ", 1)[1].replace(")", "").split(" (") or None
            print(cityCountry)
            placeInCountry.append(cityCountry and cityCountry[0] or None)
            country.append(cityCountry and len(cityCountry) > 1 and cityCountry[1] or None)
            ratingOne = i.find('span', class_ = 'r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr')
            print(ratingOne)
            rating.append(ratingOne and convertToFloat(ratingOne.text.strip().split(" (")[0].replace(",", ".")) and float(ratingOne.text.strip().split(" (")[0].replace(",", ".")) or None)
            descriptionOneWrapper = i.find("div", class_='fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr')
            print(descriptionOneWrapper)
            descriptionOne = descriptionOneWrapper and descriptionOneWrapper.find("span", class_='t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr') and descriptionOneWrapper.find("span", class_='t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr').text.strip() or None
            descriptionHotel.append(descriptionOne)
            quantityOfBedOne = i.find_all("div", class_='fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr')[-1].find("span", class_="dir dir-ltr")
            print(quantityOfBedOne)
            quantityOfBed.append(quantityOfBedOne and quantityOfBedOne.text.strip().split(" ")[0].isdigit() and int(quantityOfBedOne.text.strip().split(" ")[0]) or None)
            amountOne = i.find("span", class_="_14y1gc").find("span", class_ = "a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr")
            print(amountOne)
            amount.append(amountOne and int(amountOne.text.split("₽")[0].replace(" ", "").replace("\u00a0", "")) or None)
    
    
df = pd.DataFrame({
    "region": region,
    "place": placeInCountry,
    "country": country,
    "rating": rating,
    "description": descriptionHotel,
    'quantity of bed': quantityOfBed,
    "amount": amount
})    
    
        
driver.quit()
# Out:
# https://www.airbnb.ru/s/%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&place_id=ChIJhdqtz4aI7UYRefD8s-aZ73I&date_picker_type=calendar&checkin=2024-01-01&checkout=2024-01-31&source=structured_search_input_header&search_type=filter_change&query=%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0&price_filter_num_nights=30&federated_search_session_id=54418551-df51-4f4c-884b-a85f314a556c&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_684739345543841626">Домик, Tyin (Норвегия)</div>
# ['Tyin', 'Норвегия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,85 (47)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Рыбацкая хижина от Melviktjern</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">178 174₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_12308328">Дом, Loutraki (Греция)</div>
# ['Loutraki', 'Греция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,96 (138)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Панорамная вилла в OliveGroves</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">269 473₽ в месяц при начальной цене 311 555₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_40959258">Жилье на ферме, Brolio (Италия)</div>
# ['Brolio', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,88 (8)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Сельская местность в Тоскане | Фермерский дом в Сант-Анджело с бассейном</span></div>
# <span class="dir dir-ltr">1 двуспальная кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">259 578₽ в месяц при начальной цене 346 104₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_915713636832262612">Вилла, Kaş (Турция)</div>
# ['Kaş', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">5,0 (7)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">BayhillRoof 2- TimberFrame с собственным бассейном.</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">189 796₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_601402937647040717">Дом, Camerino (Италия)</div>
# ['Camerino', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,71 (38)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">История и сады в ректории замка</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">304 950₽ в месяц при начальной цене 395 020₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_722828842697763039">Жилье на ферме, Şarköy (Турция)</div>
# ['Şarköy', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,88 (26)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Виноградник вдали от цивилизации и дом в оливковом саду.</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">254 071₽ в месяц при начальной цене 279 087₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_46155653">Фермерский домик, Kaş (Турция)</div>
# ['Kaş', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,84 (37)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Вилла Elisam</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">233 369₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_48107685">Трулло, Provincia di Brindisi (Италия)</div>
# ['Provincia di Brindisi', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,94 (47)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="en">Трулло Аменил</span></div>
# <span class="dir dir-ltr">8 кроватей</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">243 139₽ в месяц при начальной цене 486 278₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_49537868">Гостевой дом, Alver (Норвегия)</div>
# ['Alver', 'Норвегия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,88 (49)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="no">Cozy cottage with garden</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">146 925₽ в месяц при начальной цене 205 262₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_626702449989035093">Вилла, Фетхие (Турция)</div>
# ['Фетхие', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,45 (22)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Вилья-Гера-ЭЛЮДЕНИЗ</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">240 264₽ в месяц при начальной цене 263 864₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_902656975486180181">Дом, Lipnica Górna (Польша)</div>
# ['Lipnica Górna', 'Польша']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,94 (16)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Буковский лес.</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">361 981₽ в месяц при начальной цене 499 583₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_34203329">Вилла, Skouloufia (Греция)</div>
# ['Skouloufia', 'Греция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,98 (88)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="en">Aegean Sunset Villas &amp; Spa 'Sea'</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">665 873₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_7570620">Вилла, Sessa Cilento (Италия)</div>
# ['Sessa Cilento', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,84 (95)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="en">Rural House  in Cilento National Park</span></div>
# <span class="dir dir-ltr">5 кроватей</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">208 430₽ в месяц при начальной цене 254 498₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_48653556">Квартира, Nisi (Греция)</div>
# ['Nisi', 'Греция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,92 (25)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Пляжные апартаменты « Армония»</span></div>
# <span class="dir dir-ltr">4 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">240 217₽ в месяц при начальной цене 263 841₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_41348454">Квартира, Plage des Nations (Марокко)</div>
# ['Plage des Nations', 'Марокко']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,78 (27)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Atlantic Ocean Family Suite</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">266 348₽ в месяц при начальной цене 325 410₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_862733170776311015">Дом, Анталья (Турция)</div>
# ['Анталья', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">5,0 (19)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Вилла Yalı (Bayındır Kas) Вид на море и природу</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">160 043₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_26649814">Ветряная мельница, Marinhas (Португалия)</div>
# ['Marinhas', 'Португалия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,86 (176)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Мельница</span></div>
# <span class="dir dir-ltr">1 кровать шириной 110–124 см</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">124 021₽ в месяц при начальной цене 170 976₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_110070">Дом, Пантеллерия (Италия)</div>
# ['Пантеллерия', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,87 (85)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">ИДЕАЛЬНОЕ МЕСТО - эксклюзивное использование дома</span></div>
# <span class="dir dir-ltr">Проверенный быстрый Wi-Fi</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">410 264₽ в месяц</span>
# https://www.airbnb.ru/s/%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&place_id=ChIJhdqtz4aI7UYRefD8s-aZ73I&date_picker_type=calendar&checkin=2024-01-01&checkout=2024-01-31&source=structured_search_input_header&search_type=filter_change&query=%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0&price_filter_num_nights=30&federated_search_session_id=54418551-df51-4f4c-884b-a85f314a556c&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjoxOCwidmVyc2lvbiI6MX0%3D
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_7209994">Комната в гостинице, Muratpaşa (Турция)</div>
# ['Muratpaşa', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,74 (258)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">KALEICI BACCHUS HOTEL DENISE MANZARALI  TATILIAN  501</span></div>
# <span class="dir dir-ltr">1 кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">158 256₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_24763051">Домик, Rauma (Норвегия)</div>
# ['Rauma', 'Норвегия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,99 (112)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Ромсдальское счастье, за хорошие впечатления.</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">1 432 986₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_37469831">Микродом, Краков (Польша)</div>
# ['Краков', 'Польша']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,88 (66)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">хижина  на траве</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">216 446₽ в месяц при начальной цене 349 859₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_295958">Юрта, Hollern-Twielenfleth (Германия)</div>
# ['Hollern-Twielenfleth', 'Германия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,76 (324)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Монгольская юрта в Старой Земле</span></div>
# <span class="dir dir-ltr">4 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">87 895₽ в месяц при начальной цене 246 181₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_50024396">Квартира, Terque (Испания)</div>
# ['Terque', 'Испания']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,95 (58)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Уютная квартира В традиционном оранжевом фермерском доме</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">123 438₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_30252603">Дом, Jondal kommune (Норвегия)</div>
# ['Jondal kommune', 'Норвегия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,82 (95)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Красивая Харопасность, Фольгефонна, Троллтунга, Джондал</span></div>
# <span class="dir dir-ltr">8 кроватей</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">230 425₽ в месяц при начальной цене 309 908₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_43205707">Домик, Ualand (Норвегия)</div>
# ['Ualand', 'Норвегия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,83 (130)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Уютный коттедж в живописном окружении | 2</span></div>
# <span class="dir dir-ltr">2 двуспальные кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">127 724₽ в месяц при начальной цене 165 361₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_23199271">Комната, Montale Rangone, Modena (Италия)</div>
# ['Montale Rangone, Modena', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,85 (174)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">КАМЕРА LACORTE BLU РЯДОМ С FERRARI С ЧАСТНЫМ ПАРКОМ</span></div>
# None
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">172 784₽ в месяц при начальной цене 223 725₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_49809286">Дом, Karistos (Греция)</div>
# ['Karistos', 'Греция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,95 (22)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Частный дом Deluxe с выдающимся видом на море</span></div>
# <span class="dir dir-ltr">1 двуспальная кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">210 377₽ в месяц при начальной цене 290 110₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_921039964573876287">Домик, Yeniköy (Турция)</div>
# ['Yeniköy', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,86 (35)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Бунгало Deluxe Bungalow</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">247 562₽ в месяц при начальной цене 332 956₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_615911429712664050">Кондоминиум, Kotor (Черногория)</div>
# ['Kotor', 'Черногория']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">5,0 (109)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Потрясающий вид, пентхаус - бассейн и бесплатная парковка.</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">262 036₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_826333065966299600">Дом, Alicante (Alacant) (Испания)</div>
# ['Alicante', 'Alacant', 'Испания']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,95 (21)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Тропический ретрит с ванной - настоящая скрытая жемчужина!</span></div>
# <span class="dir dir-ltr">1 кровать 190x203 см</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">356 969₽ в месяц при начальной цене 446 546₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_634664891165502083">Дом, Фаро (Португалия)</div>
# ['Фаро', 'Португалия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,97 (76)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Пляжный фасад, милый двухквартирный дом в Фару</span></div>
# <span class="dir dir-ltr">4 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">775 652₽ в месяц при начальной цене 896 951₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_36461406">Хижина, Șelari (Румыния)</div>
# ['Șelari', 'Румыния']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,96 (91)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Домик дружбы (земля дружбы)</span></div>
# <span class="dir dir-ltr">1 двуспальная кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">74 171₽ в месяц при начальной цене 102 367₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_810095955595034201">Вилла, Arbatax (Италия)</div>
# ['Arbatax', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,54 (24)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Вилла с частным бассейном и садом рядом с пляжем.</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">272 876₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_54232316">Квартира, San Vito lo capo (Италия)</div>
# ['San Vito lo capo', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,72 (69)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Пляж Macari35 S. V. lo Capo, бассейн, трекинг</span></div>
# <span class="dir dir-ltr">Проверенный быстрый Wi-Fi</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">184 533₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_891267589397066774">Квартира, Кане-ан-Руссийон (Франция)</div>
# ['Кане-ан-Руссийон', 'Франция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,8 (41)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Escape - отличный вид на море!</span></div>
# <span class="dir dir-ltr">Проверенный быстрый Wi-Fi</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">173 820₽ в месяц при начальной цене 193 133₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_32547522">Квартира, Копенгаген (Дания)</div>
# ['Копенгаген', 'Дания']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,78 (660)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Апартаменты Nord Hotel | Апартаменты-студии | Круглосуточное обслуживание | Спальных мест 3</span></div>
# <span class="dir dir-ltr">1 кровать 152x203 см</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">251 752₽ в месяц при начальной цене 299 704₽</span>
# https://www.airbnb.ru/s/%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&place_id=ChIJhdqtz4aI7UYRefD8s-aZ73I&date_picker_type=calendar&checkin=2024-01-01&checkout=2024-01-31&source=structured_search_input_header&search_type=filter_change&query=%D0%95%D0%B2%D1%80%D0%BE%D0%BF%D0%B0&price_filter_num_nights=30&federated_search_session_id=54418551-df51-4f4c-884b-a85f314a556c&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MSwiaXRlbXNfb2Zmc2V0IjozNiwidmVyc2lvbiI6MX0%3D
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_568019562603836261">Вилла, Итри (Италия)</div>
# ['Итри', 'Италия']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,78 (41)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Вилья-Фортуна</span></div>
# <span class="dir dir-ltr">10 кроватей</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">217 297₽ в месяц при начальной цене 299 423₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_50135620">Вилла, Zeytinburnu (Турция)</div>
# ['Zeytinburnu', 'Турция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,76 (33)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Роскошная квартира Radisson Blu/Ottomare Suites</span></div>
# <span class="dir dir-ltr">1 кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">343 548₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_620270497150574876">Кондоминиум, Бенальмадена (Испания)</div>
# ['Бенальмадена', 'Испания']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,97 (34)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Великолепная квартира с бассейном на берегу океана.</span></div>
# <span class="dir dir-ltr">4 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">263 078₽ в месяц при начальной цене 362 892₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_48640305">Дом, Gennes-Val-de-Loire (Франция)</div>
# ['Gennes-Val-de-Loire', 'Франция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,79 (312)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="fr">2/4 persons Holidays rental, near the Loire</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">147 158₽ в месяц при начальной цене 170 192₽</span>
# ...
# ['Флоренция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,78 (45)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Лофт на зеленом острове Изолотто Веккио</span></div>
# <span class="dir dir-ltr">Проверенный быстрый Wi-Fi</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">213 006₽ в месяц при начальной цене 314 469₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_7098705">Кондоминиум, Милан</div>
# ['Милан']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,9 (30)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">ТИШИНА И ПОКОЙ В МИЛАНЕ</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">190 473₽ в месяц при начальной цене 358 308₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_1733425">Квартира, Busto Arsizio</div>
# ['Busto Arsizio']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,84 (19)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Уютная квартира в Милане и Лейк</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">152 002₽ в месяц при начальной цене 185 569₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_604037731435080110">Кондоминиум, Мессина</div>
# ['Мессина']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,92 (39)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="it">Casa Gonzaga</span></div>
# <span class="dir dir-ltr">1 двуспальная кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">143 652₽ в месяц при начальной цене 175 506₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_821491646097988110">Кондоминиум, Polignano a Mare</div>
# ['Polignano a Mare']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,5 (12)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Роскошное жилье в Сан-Вито</span></div>
# <span class="dir dir-ltr">Отдельное рабочее место</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">213 962₽ в месяц при начальной цене 267 453₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_938285934056631967">Квартира, Isola Sacra</div>
# ['Isola Sacra']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,67 (15)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="en">Casa Margot - Fiumicino Airport &amp; Sea</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">164 194₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_956412810162729617">Вилла, Pedara</div>
# ['Pedara']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">5,0 (13)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Одиночная вилла: эвфемия</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">98 508₽ в месяц при начальной цене 135 835₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_934649180870197609">Квартира, Флоренция</div>
# ['Флоренция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">5,0 (15)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Уютно и светло рядом с центром города</span></div>
# <span class="dir dir-ltr">1 двуспальная кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">253 659₽ в месяц</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_886866429572808546">Лофт, Torre del Lago Puccini</div>
# ['Torre del Lago Puccini']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,5 (8)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Чердак между морем, озером и сосновым лесом</span></div>
# <span class="dir dir-ltr">1 кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">110 429₽ в месяц при начальной цене 134 842₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_636062018924846524">Кондоминиум, Tortoreto Lido</div>
# ['Tortoreto Lido']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,89 (18)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Уютная квартира в Торторето-Лидо</span></div>
# <span class="dir dir-ltr">3 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">85 804₽ в месяц при начальной цене 121 620₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_619423720259216143">Кондоминиум, Флоренция</div>
# ['Флоренция']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,78 (50)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="it">San Frediano Rooftop Apartment with Terrace</span></div>
# <span class="dir dir-ltr">2 кровати</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">205 866₽ в месяц при начальной цене 388 466₽</span>
# <div class="t1jojoys atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_1vgr820 atm_7l_18pqv07 atm_cs_qo5vgd atm_w4_1eetg7c atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-title" id="title_657992109632260102">Кондоминиум, Лукка</div>
# ['Лукка']
# <span aria-hidden="true" class="r1dxllyb atm_7l_18pqv07 atm_cp_1ts48j8 dir dir-ltr">4,48 (50)</span>
# <div class="fb4nyux atm_da_cbdd7d s1cjsi4j atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-subtitle"><span class="t6mzqp7 atm_g3_1kw7nm4 atm_ks_15vqwwr atm_sq_1l2sidv atm_9s_cj1kg8 atm_6w_1e54zos atm_fy_kb7nvz atm_7l_12u4tyr atm_am_qk3dho atm_ks_zryt35__1rgatj2 dir dir-ltr" data-testid="listing-card-name" lang="ru">Легко в Лукке…</span></div>
# <span class="dir dir-ltr">1 кровать</span>
# <span class="a8jt5op atm_3f_idpfg4 atm_7h_hxbz6r atm_7i_ysn8ba atm_e2_t94yts atm_ks_zryt35 atm_l8_idpfg4 atm_mk_stnw88 atm_vv_1q9ccgz atm_vy_t94yts dir dir-ltr">129 176₽ в месяц при начальной цене 146 247₽</span>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 45>()
#      41             print(amountOne)
#      42             amount.append(amountOne and int(amountOne.text.split("₽")[0].replace(" ", "").replace("\u00a0", "")) or None)
# ---> 45 df = pd.DataFrame({
#      46     "region": region,
#      47     "place": placeInCountry,
#      48     "country": country,
#      49     "rating": rating,
#      50     "description": descriptionHotel,
#      51     'quantity of bed': quantityOfBed,
#      52     "amount": amount
#      53 })
#      56 driver.quit()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:674, in _extract_index(data)
#     672 lengths = list(set(raw_lengths))
#     673 if len(lengths) > 1:
# --> 674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
#     677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#
# ValueError: All arrays must be of the same length

# %%
df = pd.DataFrame({
    "place": placeInCountry,
    "country": country,
    "rating": rating,
    "description": descriptionHotel,
    'quantity of bed': quantityOfBed,
    "amount": amount
})

# %%
df.rename(columns={'amount': 'amount в рублях'})

# %%
df['country'] = df['country'].replace({"Pg": None, "Sa": None, "Merkez": None})

# %%
df['country'].unique()
# Out:
# array(['Норвегия', 'Греция', 'Италия', 'Турция', 'Польша', 'Марокко',
#        'Португалия', 'Германия', 'Испания', 'Черногория', 'Alacant',
#        'Румыния', 'Франция', 'Дания', 'Грузия', 'Великобритания',
#        'Хорватия', 'Бельгия', 'Чехия', 'Швейцария', 'Венгрия', 'Сербия',
#        'Австрия', 'Армения', 'Нидерланды', 'Латвия', 'Швеция',
#        'Финляндия', 'Тунис', 'Словакия', 'Албания', 'Ирландия', 'США',
#        'Колумбия', 'Коста-Рика', 'Мексика', 'Аргентина', 'Бразилия',
#        'Чили', 'Перу', 'Эквадор', 'Боливия', 'Панама'], dtype=object)

# %%
df
# Out:
#                        place   country  rating  \
# 0                       Tyin  Норвегия    4.85
# 1                   Loutraki    Греция    4.96
# 2                     Brolio    Италия    4.88
# 3                        Kaş    Турция    5.00
# 4                   Camerino    Италия    4.71
# ...                      ...       ...     ...
# 1301               Флоренция    Италия    5.00
# 1302  Torre del Lago Puccini    Италия    4.50
# 1303          Tortoreto Lido    Италия    4.89
# 1304               Флоренция    Италия    4.78
# 1305                   Лукка    Италия    4.48
#
#                                             description  quantity of bed  \
# 0                        Рыбацкая хижина от Melviktjern              3.0
# 1                        Панорамная вилла в OliveGroves              NaN
# 2     Сельская местность в Тоскане | Фермерский дом ...              1.0
# 3     BayhillRoof 2- TimberFrame с собственным бассе...              2.0
# 4                       История и сады в ректории замка              NaN
# ...                                                 ...              ...
# 1301              Уютно и светло рядом с центром города              1.0
# 1302        Чердак между морем, озером и сосновым лесом              1.0
# 1303                   Уютная квартира в Торторето-Лидо              3.0
# 1304        San Frediano Rooftop Apartment with Terrace              2.0
# 1305                                     Легко в Лукке…              1.0
#
#         amount
# 0     178174.0
# 1     269473.0
# 2     259578.0
# 3     189796.0
# 4     304950.0
# ...        ...
# 1301  253659.0
# 1302  110429.0
# 1303   85804.0
# 1304  205866.0
# 1305  129176.0
#
# [1306 rows x 6 columns]

# %%
df.tail(630)
# Out:
#                        place   country  rating  \
# 676                   Богота  Колумбия    5.00
# 677               Consolação  Бразилия     NaN
# 678                  Caxambu  Бразилия     NaN
# 679                  Caxambu  Бразилия     NaN
# 680                  Caxambu  Бразилия     NaN
# ...                      ...       ...     ...
# 1301               Флоренция    Италия    5.00
# 1302  Torre del Lago Puccini    Италия    4.50
# 1303          Tortoreto Lido    Италия    4.89
# 1304               Флоренция    Италия    4.78
# 1305                   Лукка    Италия    4.48
#
#                                          description  quantity of bed  \
# 676                                             None              NaN
# 677   Табас | Современная комната в Утешении| CS0008              1.0
# 678               VOA Hotel Caxambu - Standard Casal              1.0
# 679         VOA Hotel Caxambu - Luxo Triplo Solteiro              3.0
# 680               VOA Hotel Caxambu - Standard Casal              1.0
# ...                                              ...              ...
# 1301           Уютно и светло рядом с центром города              1.0
# 1302     Чердак между морем, озером и сосновым лесом              1.0
# 1303                Уютная квартира в Торторето-Лидо              3.0
# 1304     San Frediano Rooftop Apartment with Terrace              2.0
# 1305                                  Легко в Лукке…              1.0
#
#         amount
# 676    14243.0
# 677    96878.0
# 678        NaN
# 679        NaN
# 680        NaN
# ...        ...
# 1301  253659.0
# 1302  110429.0
# 1303   85804.0
# 1304  205866.0
# 1305  129176.0
#
# [630 rows x 6 columns]

# %%
df.loc[1039:, 'country'] = 'Италия'

# %%
df.loc[786:1038, 'country'] = 'Турция'

# %%
df.loc[(df['place'] == "Caxambu") & (df['country'].isnull()), 'country'] = "Бразилия"

# %%
df.loc[df['country'].isnull(), 'country'] = 'США'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1306 entries, 0 to 1305
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   place            1306 non-null   object
#  1   country          1306 non-null   object
#  2   rating           1306 non-null   float64
#  3   description      1306 non-null   object
#  4   quantity of bed  1306 non-null   float64
#  5   amount           1306 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 61.3+ KB

# %%
df['description'] = df['description'].replace({})

# %%
df['rating'] = df['rating'].fillna(value=df['rating'].mean())

# %%
df['quantity of bed'] = df['quantity of bed'].fillna(value=int(df['quantity of bed'].mean()))

# %%
df['amount'] = df['amount'].fillna(value=int(df['amount'].mean()))

# %%
df['description'] = df['description'].replace({None: "Отсутствует"})

# %%
df['amount'] = df['amount'].apply(lambda x: x*0.97)

# %%
df['amount_dollar'] = df['amount'].apply(lambda x: x*0.011)

# %%
df = df.rename(columns={"amount": "amount_som"})

# %%
df['amount_som'] = df['amount_som'].astype(int)

# %%
df['amount_dollar'] = df['amount_dollar'].astype(int)

# %%
df['quantity of bed'] = df['quantity of bed'].astype(int)

# %%
df
# Out:
#                        place   country  rating  \
# 0                       Tyin  Норвегия    4.85
# 1                   Loutraki    Греция    4.96
# 2                     Brolio    Италия    4.88
# 3                        Kaş    Турция    5.00
# 4                   Camerino    Италия    4.71
# ...                      ...       ...     ...
# 1301               Флоренция    Италия    5.00
# 1302  Torre del Lago Puccini    Италия    4.50
# 1303          Tortoreto Lido    Италия    4.89
# 1304               Флоренция    Италия    4.78
# 1305                   Лукка    Италия    4.48
#
#                                             description  quantity of bed  \
# 0                        Рыбацкая хижина от Melviktjern                3
# 1                        Панорамная вилла в OliveGroves                2
# 2     Сельская местность в Тоскане | Фермерский дом ...                1
# 3     BayhillRoof 2- TimberFrame с собственным бассе...                2
# 4                       История и сады в ректории замка                2
# ...                                                 ...              ...
# 1301              Уютно и светло рядом с центром города                1
# 1302        Чердак между морем, озером и сосновым лесом                1
# 1303                   Уютная квартира в Торторето-Лидо                3
# 1304        San Frediano Rooftop Apartment with Terrace                2
# 1305                                     Легко в Лукке…                1
#
#       amount_som  amount_dollar
# 0         172828           1901
# 1         261388           2875
# 2         251790           2769
# 3         184102           2025
# 4         295801           3253
# ...          ...            ...
# 1301      246049           2706
# 1302      107116           1178
# 1303       83229            915
# 1304      199690           2196
# 1305      125300           1378
#
# [1306 rows x 7 columns]

# %%
import sqlite3

# %%
import numpy as np

# %%
placesUn = df['place'].unique()

# %%
countryUn = df['country'].unique()

# %%
countryUn
# Out:
# array(['Норвегия', 'Греция', 'Италия', 'Турция', 'Польша', 'Марокко',
#        'Португалия', 'Германия', 'Испания', 'Черногория', 'Alacant',
#        'Румыния', 'Франция', 'Дания', 'Грузия', 'Великобритания',
#        'Хорватия', 'Бельгия', 'Чехия', 'Швейцария', 'Венгрия', 'Сербия',
#        'Австрия', 'Армения', 'Нидерланды', 'Латвия', 'Швеция',
#        'Финляндия', 'Тунис', 'Словакия', 'Албания', 'Ирландия', 'США',
#        'Колумбия', 'Коста-Рика', 'Мексика', 'Аргентина', 'Бразилия',
#        'Чили', 'Перу', 'Эквадор', 'Боливия', 'Панама'], dtype=object)

# %%
placesUn
# Out:
# array(['Tyin', 'Loutraki', 'Brolio', 'Kaş', 'Camerino', 'Şarköy',
#        'Provincia di Brindisi', 'Alver', 'Фетхие', 'Lipnica Górna',
#        'Skouloufia', 'Sessa Cilento', 'Nisi', 'Plage des Nations',
#        'Анталья', 'Marinhas', 'Пантеллерия', 'Muratpaşa', 'Rauma',
#        'Краков', 'Hollern-Twielenfleth', 'Terque', 'Jondal kommune',
#        'Ualand', 'Montale Rangone, Modena', 'Karistos', 'Yeniköy',
#        'Kotor', 'Alicante', 'Фаро', 'Șelari', 'Arbatax',
#        'San Vito lo capo', 'Кане-ан-Руссийон', 'Копенгаген', 'Итри',
#        'Zeytinburnu', 'Бенальмадена', 'Gennes-Val-de-Loire', 'Oued Laou',
#        'Бланес', 'Кастелу-Бранку', 'București', 'Лейпциг', 'Батуми',
#        'Torre de Benagalbón', 'Корнуолл', 'Сен-Рафаэль', 'Matulji',
#        'Анкара', 'Портимао', 'Лос-Ньетос', 'Torregrotta', 'Moulsoe',
#        'Париж', 'Аяччо', 'Сплит', 'Лиссабон', 'Эдинбург',
#        'Вильфранш-сюр-Мер', 'Ницца', 'Genouillé', 'Tassin-la-Demi-Lune',
#        'Малага', 'Lu Bagnu', "T'bilisi", 'Balçova', 'Nindorf',
#        'Konyaaltı', 'Террасини', 'Lisbon', 'Стамбул', 'ჭიათურა',
#        'Sankt Hanshaugen', 'Иксель', 'Praha 10', 'Büyükçekmece',
#        'Üsküdar', 'Чанкая', 'Кадыкёй', 'Алькудия', 'Seyhan', 'Хвидовр',
#        'Kartepe', 'Большой Лондон', 'Warszawa', "L'Étang-la-Ville",
#        'Агде', 'Buca Osb', 'Биарриц', 'Нерья', 'Vechigen',
#        "S'Illot-Cala Morlanda", 'Сон-Сервера', 'Podmaniczky', 'Алания',
#        'Гамбург', 'Cala en Porter', 'Hlavní město Praha', 'Фуэнхирола',
#        'Beograd', 'Тбилиси', 'Марбелья', 'Берлин', 'Вена', 'Албуфейра',
#        'Барселона', 'Porticcio', 'Антибы', 'Saint-Laurent-du-Var',
#        'Ереван', 'Димена', 'Канны', 'Bexbach', 'Тронхейм',
#        'Courseulles-sur-Mer', 'Wendlingen am Neckar', 'Суонси', 'Марбург',
#        'Tatsfield', 'Пезаро', 'Deinze', 'Рига', 'Пальма', 'Acharnae',
#        'Бешикташ', 'Брашов', 'Mölndal Östra', 'Монпелье', 'Lormont',
#        'Штутгарт', 'Клермон-Ферран', 'Мадрид', 'Holmenkollen', 'Неаполь',
#        'Beyoğlu', "Saint-Ouen-l'Aumône", 'Athina', 'Bakırköy', 'Konak',
#        'Хельсинки', 'Carrières-sous-Poissy', 'Руан', 'Mijoux',
#        'Страсбург', 'Рони-Су-Буа', 'Jesmond', 'Турку', 'Coswig',
#        'Drysice', 'Marigliano', 'Иври-сюр-Сен', 'Binic-Étables-sur-Mer',
#        'Bagnères-de-Luchon', 'Нуази-ле-Гран', 'Брес',
#        'Sint-Genesius-Rode', 'Baggeby-Larsberg', 'Süleymanpaşa',
#        'Beeston', 'Вроцлав', 'Site archéologique de Carthage', 'Сарагоса',
#        'Виго', 'Милан', 'Sør-Fron', 'Adalar', 'Гренобль', 'Erdemli',
#        'Tremblay-en-France', "L'Haÿ-les-Roses", 'Братислава', 'Durrës',
#        'Мугла', 'South Yorkshire', 'Dublin 9', 'Аньер-сюр-Сен', 'Рим',
#        'Duttlenheim', 'Амьен', 'Karterados', 'Pray', 'Пенсакола',
#        'Санта-Роза-Бич', 'Willis', 'Clearlake Oaks', 'Gibsonton',
#        'Панама-Сити-Бич', 'Атлантик-Сити', 'Майами-Бич',
#        'Форт-Уолтон-Бич', 'Миртл-Бич', 'Дарем', 'Mary Esther', 'Хьюстон',
#        'Шарлотта', 'Арлингтон', 'Хилтон Хэд Айленд', 'Чикаго',
#        'Сан-Диего', 'Роли', 'Lynn Haven', 'Лос-Анджелес', 'Вильмингтон',
#        'Даллас', 'Бруклин', 'Лаго-Виста', 'Ланкастер', 'Little Rock',
#        'North Augusta', 'Фаунтин Вали', 'Walled Lake', 'Норфолк',
#        'Galveston', 'Mount Calm', 'Tacoma', 'Сан-Антонио', 'Нью-Йорк',
#        'Amarillo', 'Лас-Вегас', 'Хамбл', 'Херндон', 'Greenwood Village',
#        'Абилин', 'Lovettsville', 'Вотертаун', 'Сан-Франциско', 'Lansdale',
#        'Орландо', 'League City', 'Сиэтл', 'Портленд', 'Клируотер',
#        'Ньюпорт', 'Нэшвиль', 'Норт-Миртл-Бич', 'Fort Collins', 'Рокфорд',
#        'Casa Grande', 'Бэрлингтон', 'Бирмингем', 'Санта-Ана', 'Hamtramck',
#        'Кливленд-Хайтс', 'Union', 'Ньюарк', 'Port Hueneme',
#        'Оклахома-Сити', 'Колумбус', 'Джэксонвилл', 'Роял-Оук', 'Клинтон',
#        'Саут-Бенд', 'Филадельфия', 'Милуоки', 'Сан-Хосе', 'Page',
#        'Сент-Луис', 'Лейквуд', 'Питтсбург', 'East Hartford', 'Атланта',
#        'Киссимми', 'Gallatin', 'Квинс', 'Индианаполис', 'Торранс',
#        'Феникс', 'Спрингфилд', 'Каррборо', 'Стэмфорд', 'Richmond Heights',
#        'Inverness', 'Ботелл', 'Уоррентон', 'Нью-Хейвен',
#        'Mount Laurel Township', 'Федерал-Вэй', 'Фресно', 'Порт-Исабел',
#        "О'Фаллон", 'Pearland', 'Ричмонд', 'Lima', 'Jacksboro',
#        'Морристаун', 'Эллсворт', 'Вашингтон', 'Денвер', 'Рочестер',
#        'Миннеаполис', 'Хайленд', 'Уинстон-Салем', 'Цинциннати',
#        'Постмаус', 'Детройт', 'Лонг Бич', 'Порт-Ориндж', 'Lillian',
#        'Альбукерке', 'Рокследж', 'Тампа', 'Форт-Уэйн', 'Марина дель Рэй',
#        'Девенпорт', 'Мариетта', 'Вифлеем', 'Бостон', 'Грейпвайн',
#        'Valdosta', "Lee's Summit", 'Chesterton', 'Лондейл', 'Брандон',
#        'Fitchburg', 'New Albany', 'Рентон', 'Богота', 'Acapulco ',
#        'Буэнос-Айрес', 'Кампинас', 'Чентро', 'Cambuí', 'Сан-Паулу',
#        'Liberdade', 'Куритиба', 'Vitacura', 'Rionegro', 'Belgrano',
#        'Asa Norte', 'Floresta', 'Brasília', 'Enseada do Suá', 'Barranco',
#        'Centro Histórico', 'Порто Алегре', 'Martínez', 'Paraíso',
#        'Барранкилья', 'Caballito', 'Кито', 'Медельин', 'Santa Ifigênia',
#        'Jesús María', 'Jardim Fernandes', 'Goiânia', 'Água Verde',
#        'San Miguel', 'Бразилиа', 'Palermo', 'Santa Cruz de la Sierra',
#        'Реколета', 'Натал', 'Кабеделу', 'Mairiporã', 'Pelotas', 'Риф',
#        'Лима', 'Сантьяго', 'Гуаруха', 'Ушуайя', 'Saavedra', 'Bela Vista',
#        'Villahermosa', 'Montes Claros', 'Santiago de Surco',
#        'Nova Aliança', 'Кали', 'Antioquia', 'Londrina',
#        'São Caetano do Sul', 'Colegiales', 'Jardim Apolo', 'Жундиаи',
#        'Jardim Arapongas', 'Maringá', 'Jardim Sao Dimas', 'Bello',
#        'Jardim Camburi', 'Серра', 'San Pedro', 'Araguari', 'Panamá',
#        'Ribeirão Preto', 'La Plata', 'Consolação', 'Caxambu', 'Kartal',
#        'Измир', 'Кемер', 'bodrum', 'Menderes', 'Бодрум', 'Yanıklar',
#        'Çeşme', 'Kaş, Kalkan', 'İslamlar', 'Nilüfer', 'Kayaköy',
#        'Seydikemer', 'Karaköy', 'Çalış Beach', 'Mahmutlar', 'Kaş Kalkan',
#        'Konyaalti,liman', 'Datça', 'Keçiler', 'Manavgat', 'Kâğıthane',
#        'Üzümlü', 'kuşadası', 'Muğla/Bodrum', 'Mahmutlar Belediyesi',
#        'Gündoğan', 'Дидим', 'Avsallar Belediyesi', 'Pendik', 'Buca',
#        'Başakşehir', 'Kargı', 'Kepez', 'Karşıyaka', 'Milas', 'Atakum',
#        'Bahtılı Köyü Köyü', 'Göynük Belediyesi', 'Кушадасы', 'Canneto',
#        'Anghiari', 'Сирмионе', 'Santa Flavia', 'Codaruina', 'Мета',
#        'Alicudi', 'Pompeii', 'Nereto', 'Termini', 'Палермо',
#        "Куарту-Сант'Элене", 'Fornelli', 'Gagliano del Capo',
#        'Monte Urano', 'Аси Кастелло', 'Теулада', 'Tertenia', 'Catabbio',
#        'Cala Liberotto', 'Calci', 'Помпеи', 'Палау', 'Solarino',
#        'Lotzorai', 'Бари', 'Acquappesa', 'Chia', 'Riposto', 'Лукка',
#        'Баньо-а-Риполи', 'Santa Lucia', 'Тортоли', 'Bacoli', 'Bagheria',
#        'Figline Valdarno', 'Menfi', 'Luino', 'Рапалло', 'Пескара',
#        'Империя', 'Гаэта', 'Флоренция', 'Briatico', 'Cesano', 'Scario',
#        'Анцио', 'Чефалу', 'Castiglione del Lago ', 'Санта-Тереза Галлура',
#        'Tre Fontane', 'Ambra, Bucine', 'Verbania', 'Fratte Rosa', 'Latte',
#        'Mascalucia', 'Santa Sofia', 'Тревизо',
#        'Сан-Бенедетто дель Тронто', 'Lipari', 'Анкона', 'Вьяреджо',
#        'Lipari canneto', 'Rosolina Mare', 'Соланас', 'Castel Gandolfo',
#        'Cava de’ Tirreni', 'Bardolino', 'Bonassola', "L'Aquila",
#        'Дезенцано дель Гарда', 'Rivarolo Canavese', 'Capranica', 'Cesena',
#        'Вентимилья', 'Terzigno', 'Villaggio Turas', 'Трапани',
#        'San Casciano in Val di pesa', 'Скалеа', 'Кульери', 'Ла Специя',
#        'Torvaianica', 'Capitignano', 'Ливорно', 'Пиза', 'Алкамо',
#        'Costella', 'Ercolano', 'Torre Annunziata', 'Монополи', 'Сполето',
#        'Marina di Montenero', 'Montaretto', 'Pietrapiana',
#        'Santa Maria A Vico', 'Лечче', 'Sabaudia', 'Неттуно', 'Верона',
#        ' SALA MANDELLI', 'Таранто', 'Carro', 'Torno', 'Vivaro',
#        'Santa Maria Navarrese', 'Поццуоли', 'Реджо-ди-Калабрия',
#        'Террануова Браччолини', 'Камольи', 'San Giovanni Suergiu',
#        'Альгеро', 'Termoli', 'Stazione-fornola', 'San Silvestro', 'Recco',
#        'Volla', 'Тропеа', 'Римини', 'Villapiana Lido', 'Форио',
#        'Bellegra', 'Каррара', 'Кальяри', 'Golasecca', 'Solfarelli',
#        'Фавиньяна', 'Генуя', 'Ariccia', 'Pieve Ligure', 'Frosinone',
#        'Novara', 'Montalto Marina', 'Lecco', 'Марино', 'Монтеварчи',
#        'Montesilvano', 'Sala Comacina', 'Piumazzo', 'Gorizia',
#        'Lido di Camaiore', 'Busto Arsizio', 'Мессина', 'Polignano a Mare',
#        'Isola Sacra', 'Pedara', 'Torre del Lago Puccini',
#        'Tortoreto Lido'], dtype=object)

# %%
conn = sqlite3.connect("airbnb_stanford.db")
cur = conn.cursor()

cur.execute("""
    CREATE TABLE IF NOT EXISTS places(
        id integer primary key autoincrement,
        place TEXT
    )
""")

cur.execute("""
    CREATE TABLE IF NOT EXISTS countries(
        id integer primary key autoincrement,
        country TEXT
    )
""")
    
cur.execute("""
            CREATE TABLE IF NOT EXISTS conns_country_place(
                id_place integer not null,
                id_country integer not null,
                
                FOREIGN KEY (id_place) REFERENCES places (id),
                FOREIGN KEY (id_country) REFERENCES countries (id)
            )
""")

cur.execute("""
    CREATE TABLE IF NOT EXISTS hotels(
        id integer primary key autoincrement,
        raiting REAL,
        description TEXT,
        quantityOfBed integer,
        amount_som real,
        amount_dollar real,
        id_place integer not null,
        id_country integer not null,
        
        FOREIGN KEY (id_place) REFERENCES places (id),
        FOREIGN KEY (id_country) REFERENCES countries (id)
    )
""")


for i in placesUn:
    cur.execute("""
        INSERT INTO places(place) VALUES(?)
    """, (i, ))

for i in countryUn:
    cur.execute("""
        INSERT INTO countries(country) VALUES(?)
    """, (i,))
    
for i, row in df.iterrows():
    indexCountry = int(np.where(countryUn==row['country'])[0][0])
    indexPlace = int(np.where(placesUn==row['place'])[0][0])
    cur.execute("""
        INSERT INTO conns_country_place(id_country, id_place) VALUES(?, ?)
    """, (indexCountry, indexPlace))
    for j, row2 in df.iterrows():
        if i == j: 
            continue
        if row['country'] == row2['country'] and row['place'] != row2['place']:
            indexCountry = int(np.where(countryUn==row2['country'])[0][0])
            indexPlace = int(np.where(placesUn==row2['place'])[0][0])
            cur.execute("""
                INSERT INTO conns_country_place(id_country, id_place) VALUES(?, ?)
            """, (indexCountry, indexPlace))

for i, row in df.iterrows():
    indexCountry = int(np.where(countryUn == row['country'])[0][0])
    indexPlace = int(np.where(placesUn == row['place'])[0][0])
    cur.execute("""
        INSERT INTO hotels(raiting, description, quantityOfBed, amount_som, amount_dollar, id_place, id_country) VALUES(?, ?, ?, ?, ?, ?, ?)
    """, (row['rating'], row['description'], row['quantity of bed'], row['amount_som'], row['amount_dollar'], indexPlace, indexCountry))

conn.commit()
conn.close()
